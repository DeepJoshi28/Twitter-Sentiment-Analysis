# %% [markdown]
# **Twitter Sentiment Analysis**

# %%
import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob 

class TwitterClient(object): 
    ''' 
    Generic Twitter Class for sentiment analysis. 
    '''
    def __init__(self): 
        ''' 
        Class constructor or initialization method. 
        '''
        # keys and tokens from the Twitter Dev Console 
        consumer_key = ''
        consumer_secret = ''
        access_token = ''
        access_token_secret = ''

        # attempt authentication 
        try: 
            # create OAuthHandler object 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            # set access token and secret 
            self.auth.set_access_token(access_token, access_token_secret) 
            # create tweepy API object to fetch tweets 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 

    def clean_tweet(self, tweet): 
        ''' 
        Utility function to clean tweet text by removing links, special characters 
        using simple regex statements. 
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 

    def get_tweet_sentiment(self, tweet):
        '''
        Utility function to classify sentiment of passed tweet 
        using textblob's sentiment method 
        '''
        # create TextBlob object of passed tweet text 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        # set sentiment 
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'

    def get_tweets(self, query, count = 10):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets 
        tweets = [] 
                               
        try:
            # call twitter api to fetch tweets 
            fetched_tweets = self.api.search(q = query, count = count) 
                               
            # parsing tweets one by one 
            for tweet in fetched_tweets:
                # empty dictionary to store required params of a tweet 
                parsed_tweet = {} 
                                       
                # saving text of tweet 
                parsed_tweet['text'] = tweet.text 
                # saving sentiment of tweet 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
                                       
                # appending parsed tweet to tweets list 
                if tweet.retweet_count > 0:
                                       
                    # if tweet has retweets, ensure that it is appended only once 
                    if parsed_tweet not in tweets:
                        tweets.append(parsed_tweet)
                    else:
                        tweets.append(parsed_tweet) 
                               
            # return parsed tweets 
            return tweets 
                               
        except tweepy.TweepError as e:
            # print error (if any) 
            print("Error : " + str(e)) 

def main():
    # creating object of TwitterClient Class 
    api = TwitterClient() 
    # calling function to get tweets 
    tweets = api.get_tweets(query = 'election2019', count = 200) 
                               
    # picking positive tweets from tweets 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    # percentage of positive tweets 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    # picking negative tweets from tweets 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    # percentage of negative tweets 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
    # picking neutral tweets from tweets 
    neutraltweets = [tweet for tweet in tweets if tweet['sentiment'] == 'neutral']
    # percentage of neutral tweets 
    print("Neutral tweets percentage: {} %".format(100*len(neutraltweets)/len(tweets))) 
                               
    # printing first 10 positive tweets 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]:
        print(tweet['text']) 
                               
    # printing first 10 negative tweets 
    print("\n\nNegative tweets:")
    for tweet in ntweets[:10]:
        print(tweet['text'])
        
    # printing first 10 neutral tweets 
    print("\n\nNeutral tweets:")
    for tweet in neutraltweets[:10]:
        print(tweet['text']) 

if __name__ == "__main__":
    # calling main function
    main()
# Out:
# Positive tweets percentage: 38.095238095238095 %
# Negative tweets percentage: 22.61904761904762 %
# Neutral tweets percentage: 39.285714285714285 %
#
#
# Positive tweets:
# RT @JackWDart: I’m incredibly proud to announce that I have won the election for council in Ellacombe! Both Jermaine and I worked hard, and…
# RT @AaronDodd: I told you not to do a first debate @ScottMorrisonMP. You ignored me. I told you not to do another. You didn't listen. Now a…
# RT @AaronDodd: I told you not to do a first debate @ScottMorrisonMP. You ignored me. I told you not to do another. You didn't listen. Now a…
# RT @1petermartin: Morrison: Both of us are committed to action on climate change
#
# Shorten: If the Coalition was committed to action on clim…
# RT @ReclaimAnglesea: I wonder if @ScottMorrisonMP has engaged his brain to think about the fact that the large numbers of students striking…
# RT @JackWDart: I’m incredibly proud to announce that I have won the election for council in Ellacombe! Both Jermaine and I worked hard, and…
# RT @JackWDart: I’m incredibly proud to announce that I have won the election for council in Ellacombe! Both Jermaine and I worked hard, and…
# RT @TheGirlMannix: #Election2019 this is too funny 😂 #michaeljackson #healyraes https://t.co/S9voGc5bKD
# RT @AaronDodd: I told you not to do a first debate @ScottMorrisonMP. You ignored me. I told you not to do another. You didn't listen. Now a…
# RT @Greekboy8: RT BREAKING NEWS: Funny #Election2019 Don’t suggest this is why @Conservatives vote is collapsing
#
# #UniversalCredit regulat…
#
#
# Negative tweets:
# RT @_sara_jade_: Based on his continuous rapid blinking on #PeoplesForum when Bill was speaking, indicates Morrison was anxious &amp; stressed…
# RT @johndowe49: @Kaitlynkitzan @JustinTrudeau Why does he continue to run away from our sick and disabled #mefloquine veterans?
#
# #AskingFo…
# RT @politicalcog: I want a party that doesn't plant fear, that doesn't offer only hate or division, that has a plan for climate change and…
# RT @labor_trash: Labor keep telling us that #NegativeGearing is bad for us but Tanya owns 4 Negatively Geared properties. #auspol #AusVotes…
# RT @politicalcog: I want a party that doesn't plant fear, that doesn't offer only hate or division, that has a plan for climate change and…
# RT @_sara_jade_: Jen not ‘thrilled’ to be there, eyes widen fear, teeth baring forced high stress smile. Both fake smiles. Scomo no zygomat…
# RT @politicalcog: I want a party that doesn't plant fear, that doesn't offer only hate or division, that has a plan for climate change and…
# RT @labor_trash: Labor keep telling us that #NegativeGearing is bad for us but Mark owns 6 Negatively Geared properties. #auspol  #AusVotes…
# RT @PaulFisheredit: Lots of tired eyes in @IliffeMedia and @Kent_Online newsrooms today after a long night and day after of #Election2019 c…
# RT @_sara_jade_: Based on his continuous rapid blinking on #PeoplesForum when Bill was speaking, indicates Morrison was anxious &amp; stressed…
#
#
# Neutral tweets:
# RT @iamsunnydeol: ਭੰਗੂੜੀ (ਸੁਜਾਨਪੁਰ ਵਿਧਾਨ ਸਭਾ)  ਦੇ ਲੋਕਾਂ ਵੱਲੋਂ ਮਿਲਿਆ ਪਿਆਰ ਤੇ ਸਤਿਕਾਰ, ਤਹਿ ਦਿਲੋਂ ਕਰਦਾ ਹਾਂ ਧੰਨਵਾਦ |
# भंगूडी (सुजानपुर विधानसभा )…
# RT @liamyoung: I’m here for @BarryGardiner’s iPad case @totaleclipse96 sticker on BBC #Election2019 coverage😂 #DontBuyTheSun https://t.co/A…
# RT @JindalTeam: हिसार लोकसभा के उकलाना चुनाव कार्यालय में कांग्रेस प्रत्याशी @bbhavyabishnoi के समर्थन में प्रचार करने पहुंचे @MPNaveenJind…
# RT @joltinitiative: ELECTION DAY IS TOMORROW! Find where to vote at https://t.co/4P6Qk2acCY
#
# #Election2019 #MayThe4thBeWithYou #Texas
#
# htt…
# RT @ynews: Residents the Gugulethu community feel overlooked by @Our_DA provincial government and promise to vote for @MYANC in the #Electi…
# RT @ReclaimAnglesea: I briefly wondered if I had been transported back to April Fools Day when I heard on #ABCnews that @ScottMorrisonMP wo…
# RT @Go_CheshireWest: Election result: Davenham, Moulton and Kingsmead Ward - Elton Philip Watson (Con) and Helen Catherine Weltman (Con) -…
# RT @joltinitiative: ELECTION DAY IS TOMORROW! Find where to vote at https://t.co/4P6Qk2acCY
#
# #Election2019 #MayThe4thBeWithYou #Texas
#
# htt…
# RT @joltinitiative: ELECTION DAY IS TOMORROW! Find where to vote at https://t.co/4P6Qk2acCY
#
# #Election2019 #MayThe4thBeWithYou #Texas
#
# htt…
# RT @iamsunnydeol: ਡੇਰਾ ਬਾਬਾ ਨਾਨਕ ਦਰਬਾਰ ਸਾਹਿਬ  ਵਿਖੇ ਭਾਰਤੀ ਜਨਤਾ ਪਾਰਟੀ ਅਤੇ ਸ਼੍ਰੋਮਣੀ ਅਕਾਲੀ ਦਲ ਗਠਜੋੜ ਦੇ ਉਮੀਦਵਾਰ ਸਨੀ ਦਿਓਲ ਮੱਥਾ ਟੇਕਦੇ ਹੋਏ l
# #sunny…
